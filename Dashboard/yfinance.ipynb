# %% [markdown]
# Take the data from Yahoo Finance

# %%
pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      ---------------------------------------- 10.2/939.5 kB ? eta -:--:--
#      - ----------------------------------- 30.7/939.5 kB 325.1 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/939.5 kB 325.1 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/939.5 kB 325.1 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/939.5 kB 325.1 kB/s eta 0:00:03
#      ---- ------------------------------- 122.9/939.5 kB 423.5 kB/s eta 0:00:02
#      ----- ------------------------------ 133.1/939.5 kB 392.6 kB/s eta 0:00:03
#      ----- ------------------------------ 153.6/939.5 kB 398.2 kB/s eta 0:00:02
#      ------ ----------------------------- 174.1/939.5 kB 402.6 kB/s eta 0:00:02
#      ------- ---------------------------- 184.3/939.5 kB 397.4 kB/s eta 0:00:02
#      -------- --------------------------- 215.0/939.5 kB 409.6 kB/s eta 0:00:02
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
# take the Bitcoin data 
ticker='BTC-USD'
data =yf.download(ticker, start="2011-01-01",end="2024-10-25")
print(data.head())
data.to_csv(f'{ticker}.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                        BTC-USD     BTC-USD     BTC-USD     BTC-USD
# Date
# 2014-09-17 00:00:00+00:00  457.334015  457.334015  468.174011  452.421997
# 2014-09-18 00:00:00+00:00  424.440002  424.440002  456.859985  413.104004
# 2014-09-19 00:00:00+00:00  394.795990  394.795990  427.834991  384.532013
# 2014-09-20 00:00:00+00:00  408.903992  408.903992  423.295990  389.882996
# 2014-09-21 00:00:00+00:00  398.821014  398.821014  412.425995  393.181000
#
# Price                            Open    Volume
# Ticker                        BTC-USD   BTC-USD
# Date
# 2014-09-17 00:00:00+00:00  465.864014  21056800
# 2014-09-18 00:00:00+00:00  456.859985  34483200
# 2014-09-19 00:00:00+00:00  424.102997  37919700
# 2014-09-20 00:00:00+00:00  394.673004  36863600
# 2014-09-21 00:00:00+00:00  408.084991  26580100

# %%
python download_stock_data.ipynb
# Out:
#   Cell In[3], line 1
#     python download_stock_data.ipynb
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.read_csv('BTC-USD.csv')
df.head()
# Out:
#                        Price           Adj Close               Close  \
# 0                     Ticker             BTC-USD             BTC-USD
# 1                       Date                 NaN                 NaN
# 2  2014-09-17 00:00:00+00:00   457.3340148925781   457.3340148925781
# 3  2014-09-18 00:00:00+00:00  424.44000244140625  424.44000244140625
# 4  2014-09-19 00:00:00+00:00   394.7959899902344   394.7959899902344
#
#                  High                Low               Open    Volume
# 0             BTC-USD            BTC-USD            BTC-USD   BTC-USD
# 1                 NaN                NaN                NaN       NaN
# 2  468.17401123046875  452.4219970703125   465.864013671875  21056800
# 3   456.8599853515625    413.10400390625  456.8599853515625  34483200
# 4   427.8349914550781  384.5320129394531  424.1029968261719  37919700

# %%
import pandas as pd
df = pd.read_csv('AAPL_data.csv')
df.head()
# Out:
#                        Price           Adj Close               Close  \
# 0                     Ticker                AAPL                AAPL
# 1                       Date                 NaN                 NaN
# 2  2024-01-02 00:00:00+00:00  184.93821716308594  185.63999938964844
# 3  2024-01-03 00:00:00+00:00    183.553466796875              184.25
# 4  2024-01-04 00:00:00+00:00   181.2223358154297  181.91000366210938
#
#                  High                 Low                Open    Volume
# 0                AAPL                AAPL                AAPL      AAPL
# 1                 NaN                 NaN                 NaN       NaN
# 2  188.44000244140625  183.88999938964844  187.14999389648438  82488700
# 3   185.8800048828125  183.42999267578125  184.22000122070312  58414500
# 4  183.08999633789062   180.8800048828125  182.14999389648438  71983600
